# %%
graph_data =[(1, ([31, 12, 82, 42, 58], 1.0)),
 (2, ([18, 94, 15, 51, 68], 1.0)),
 (3, ([41, 17, 82, 87, 52], 1.0)),
 (4, ([72, 82, 71, 84, 3, 7, 46], 1.0)),
 (5, ([65, 47, 22, 59, 53, 90], 1.0)),
 (6, ([61, 24], 1.0)),
 (7, ([31, 70, 11, 48, 9, 56], 1.0)),
 (8, ([52, 62, 30, 10], 1.0)),
 (9, ([74, 59, 72, 35, 91, 71], 1.0)),
 (10, ([75, 68, 81, 93, 8, 94, 34], 1.0)),
 (11, ([92, 41, 84, 2, 77, 70, 54], 1.0)),
 (12, ([14, 31, 8, 85, 54], 1.0)),
 (13, ([31, 43, 100, 89, 40, 35, 84], 1.0)),
 (14, ([68], 1.0)),
 (15, ([1, 38], 1.0)),
 (16, ([17, 71, 92, 63, 79], 1.0)),
 (17, ([99], 1.0)),
 (18, ([21], 1.0)),
 (19, ([89, 95, 20, 49], 1.0)),
 (20, ([84, 98, 9, 72, 32], 1.0)),
 (21, ([29, 7], 1.0)),
 (22, ([64, 94, 49, 46, 48, 100], 1.0)),
 (23, ([99, 76, 84, 30], 1.0)),
 (24, ([10, 8, 73, 49], 1.0)),
 (25, ([], 1.0)),
 (26, ([], 1.0)),
 (27, ([32], 1.0)),
 (28, ([], 1.0)),
 (29, ([68, 41, 25, 14, 84, 38], 1.0)),
 (30, ([83, 65, 8, 72, 73], 1.0)),
 (31, ([37, 8, 21, 24], 1.0)),
 (32, ([100, 34], 1.0)),
 (33, ([97, 2, 75, 99, 78, 96, 67], 1.0)),
 (34, ([], 1.0)),
 (35, ([18, 26], 1.0)),
 (36, ([24], 1.0)),
 (37, ([39, 22], 1.0)),
 (38, ([86, 97], 1.0)),
 (39, ([68, 78, 81, 99, 29, 80], 1.0)),
 (40, ([21], 1.0)),
 (41, ([], 1.0)),
 (42, ([96], 1.0)),
 (43, ([56, 93, 7, 33, 59], 1.0)),
 (44, ([66, 47], 1.0)),
 (45, ([], 1.0)),
 (46, ([85, 5, 29], 1.0)),
 (47, ([32, 61, 49, 97], 1.0)),
 (48, ([84], 1.0)),
 (49, ([], 1.0)),
 (50, ([42, 90, 34], 1.0)),
 (51, ([23, 3, 92], 1.0)),
 (52, ([11, 9, 85], 1.0)),
 (53, ([83, 88, 27, 40, 32, 76], 1.0)),
 (54, ([51, 30, 18, 85, 83, 25, 47], 1.0)),
 (55, ([40, 82, 63, 5, 58], 1.0)),
 (56, ([90, 71, 93, 59, 68, 89], 1.0)),
 (57, ([87, 53, 52, 31, 2, 92], 1.0)),
 (58, ([56, 35, 81], 1.0)),
 (59, ([84, 98], 1.0)),
 (60, ([81, 63, 76, 87, 100], 1.0)),
 (61, ([35, 82, 5, 41], 1.0)),
 (62, ([21, 36], 1.0)),
 (63, ([59, 14], 1.0)),
 (64, ([55, 66, 73, 10], 1.0)),
 (65, ([21, 61, 33, 9, 37], 1.0)),
 (66, ([88, 98, 61, 71, 68, 38], 1.0)),
 (67, ([93, 29, 97, 60, 44], 1.0)),
 (68, ([49, 94, 75, 45], 1.0)),
 (69, ([42], 1.0)),
 (70, ([48, 26, 25, 3, 53, 81, 65], 1.0)),
 (71, ([34, 69, 8], 1.0)),
 (72, ([71, 75, 44, 54], 1.0)),
 (73, ([86, 23, 70, 83, 84, 2, 53], 1.0)),
 (74, ([], 1.0)),
 (75, ([50, 28, 85, 72], 1.0)),
 (76, ([], 1.0)),
 (77, ([55, 85, 61, 99, 75, 33, 73], 1.0)),
 (78, ([28], 1.0)),
 (79, ([40, 95, 75, 65], 1.0)),
 (80, ([10], 1.0)),
 (81, ([15, 92], 1.0)),
 (82, ([14, 87, 89, 9, 67], 1.0)),
 (83, ([33, 31, 15, 32, 52], 1.0)),
 (84, ([67, 94, 91, 78, 73, 45, 89], 1.0)),
 (85, ([], 1.0)),
 (86, ([18, 56], 1.0)),
 (87, ([70, 11, 13, 16, 14, 73], 1.0)),
 (88, ([68, 24, 67, 17, 91], 1.0)),
 (89, ([52, 29, 31, 54, 28, 90, 56], 1.0)),
 (90, ([96, 94], 1.0)),
 (91, ([21, 54], 1.0)),
 (92, ([56, 66, 68, 69, 31], 1.0)),
 (93, ([49, 94, 73, 38, 74, 44, 37], 1.0)),
 (94, ([75, 76, 83, 85], 1.0)),
 (95, ([87, 53], 1.0)),
 (96, ([60, 26, 61, 80, 78], 1.0)),
 (97, ([86, 81, 98, 91, 56, 18], 1.0)),
 (98, ([74, 46], 1.0)),
 (99, ([12, 31, 36, 28, 10, 5, 88], 1.0)),
 (100, ([56, 62], 1.0))]

# Convert the data into the desired format
formatted_data = {}
for node, (neighbors, _) in graph_data:
    if neighbors:
        formatted_data[node] = {str(neighbor): 1 for neighbor in neighbors}
    else:
        formatted_data[node] = {}

# Write the data to a file
with open("wikipedia_example.txt", "w") as f:
    for node, neighbors in formatted_data.items():
        f.write(f"{node} {neighbors}\n")

# %% [markdown]
# # For MR Job
# ##### Slight Modification in spacing may be needed for nodes of single digit(One tab distace after every node)

# %%
graph_data =[(1, ([38, 95, 36, 67, 94, 65], 1.0)),
 (2, ([32], 1.0)),
 (3, ([97, 49, 34, 20, 83], 1.0)),
 (4, ([78, 65], 1.0)),
 (5, ([97, 56, 32], 1.0)),
 (6, ([35, 33, 39, 8, 82, 94, 17], 1.0)),
 (7, ([75, 11, 28, 78, 17, 14, 37], 1.0)),
 (8, ([92, 83, 84, 77, 94, 24], 1.0)),
 (9, ([60, 81], 1.0)),
 (10, ([37, 40, 18, 11, 100, 44, 89], 1.0)),
 (11, ([39, 57, 22, 26, 63, 30, 8], 1.0)),
 (12, ([47, 95], 1.0)),
 (13, ([42, 73, 97, 50, 3, 92, 4], 1.0)),
 (14, ([42, 79, 87, 63, 36], 1.0)),
 (15, ([2, 95, 94, 83, 42, 67, 60], 1.0)),
 (16, ([96], 1.0)),
 (17, ([78, 16, 73, 8, 18], 1.0)),
 (18, ([94, 28, 29, 64, 69, 37, 36], 1.0)),
 (19, ([40, 84, 25], 1.0)),
 (20, ([79, 15], 1.0)),
 (21, ([61, 67, 37, 24, 23, 96], 1.0)),
 (22, ([23, 13, 99, 69, 89, 52, 88], 1.0)),
 (23, ([62, 53, 77, 31, 63, 80], 1.0)),
 (24, ([38, 35], 1.0)),
 (25, ([19, 72, 47, 99, 44, 39, 94], 1.0)),
 (26, ([40, 98], 1.0)),
 (27, ([15, 28], 1.0)),
 (28, ([94, 45, 73, 71, 7, 100, 25], 1.0)),
 (29, ([38, 36, 79, 39, 2], 1.0)),
 (30, ([15, 5], 1.0)),
 (31, ([88, 97, 45, 22, 65, 79, 29], 1.0)),
 (32, ([81, 96, 52, 70], 1.0)),
 (33, ([39, 73, 70, 99, 47], 1.0)),
 (34, ([5, 71, 7, 67, 95, 16, 62], 1.0)),
 (35, ([4], 1.0)),
 (36, ([95, 81, 42, 53], 1.0)),
 (37, ([18, 75, 98, 29], 1.0)),
 (38, ([35], 1.0)),
 (39, ([29, 21, 17], 1.0)),
 (40, ([52, 73, 30, 90, 10, 33], 1.0)),
 (41, ([86, 92, 84, 63], 1.0)),
 (42, ([16, 14, 8, 36, 5, 54], 1.0)),
 (43, ([94, 11, 77, 5], 1.0)),
 (44, ([97, 17, 66, 54], 1.0)),
 (45, ([70, 46, 98, 7], 1.0)),
 (46, ([47, 64, 62, 77, 90], 1.0)),
 (47, ([68, 7, 1], 1.0)),
 (48, ([63, 13, 6, 79], 1.0)),
 (49, ([54, 19, 2, 63], 1.0)),
 (50, ([36, 99, 83, 58, 89], 1.0)),
 (51, ([35, 82, 36], 1.0)),
 (52, ([20, 22, 4], 1.0)),
 (53, ([30, 97, 94, 70], 1.0)),
 (54, ([20, 93], 1.0)),
 (55, ([100, 5], 1.0)),
 (56, ([10, 99], 1.0)),
 (57, ([23, 4], 1.0)),
 (58, ([82, 37, 85, 96], 1.0)),
 (59, ([25, 39, 28], 1.0)),
 (60, ([96], 1.0)),
 (61, ([79, 98, 2, 18], 1.0)),
 (62, ([9, 95, 6, 51, 60], 1.0)),
 (63, ([27, 70, 13], 1.0)),
 (64, ([57], 1.0)),
 (65, ([43, 46, 99, 41, 53, 32, 33], 1.0)),
 (66, ([80, 27, 40, 11], 1.0)),
 (67, ([84, 85, 13, 12], 1.0)),
 (68, ([90], 1.0)),
 (69, ([43, 65, 64, 18], 1.0)),
 (70, ([82, 11], 1.0)),
 (71, ([90, 19], 1.0)),
 (72, ([94, 96], 1.0)),
 (73, ([53, 95, 91], 1.0)),
 (74, ([19, 92, 75, 69, 54], 1.0)),
 (75, ([27, 23, 3, 92, 78, 74], 1.0)),
 (76, ([58, 100], 1.0)),
 (77, ([71], 1.0)),
 (78, ([11, 43, 95], 1.0)),
 (79, ([14, 97, 94, 9, 100], 1.0)),
 (80, ([27], 1.0)),
 (81, ([7, 87, 96, 17], 1.0)),
 (82, ([1, 47], 1.0)),
 (83, ([29, 35], 1.0)),
 (84, ([8, 65], 1.0)),
 (85, ([52, 7, 57, 22, 73], 1.0)),
 (86, ([68, 94, 96, 12], 1.0)),
 (87, ([47, 70, 92, 19, 79, 99, 25], 1.0)),
 (88, ([15, 55], 1.0)),
 (89, ([2], 1.0)),
 (90, ([73, 11, 68], 1.0)),
 (91, ([52, 6, 63, 35, 17, 54], 1.0)),
 (92, ([53, 2], 1.0)),
 (93, ([68, 42, 98, 55, 100], 1.0)),
 (94, ([45, 98, 61, 33, 77], 1.0)),
 (95, ([56], 1.0)),
 (96, ([8, 31, 80, 75, 72, 85], 1.0)),
 (97, ([80, 64, 3, 58, 53, 17, 15], 1.0)),
 (98, ([13, 30, 2, 66], 1.0)),
 (99, ([83, 35, 66, 48, 67, 34, 16], 1.0)),
 (100, ([29, 84, 56, 27, 64], 1.0))]

# Convert the data into the desired format
formatted_data = {}
for node, (neighbors, _) in graph_data:
    if neighbors:
        formatted_data[node] = {str(neighbor): 1 for neighbor in neighbors}
    else:
        formatted_data[node] = {}

# Write the data to a file with space after the node and two tabs
with open("wikipedia_example.txt", "w") as f:
    for node, neighbors in formatted_data.items():
        f.write(f"{node} \t{neighbors}\n")

# %%
formatted_data = {}
for node, (neighbors, _) in graph_data:
    formatted_data[node] = neighbors

# Write the data to a file
with open("graph_representation.txt", "w") as f:
    for node, neighbors in formatted_data.items():
        f.write(f"{node}: {neighbors},\n")

# %% [markdown]
# # Getting Simple Adjacency List

# %%
formatted_data = {}
for node, (neighbors, _) in graph_data:
    formatted_data[node] = neighbors

# Write the data to a file
with open("graph_representation11.txt", "w") as f:
    for node, neighbors in formatted_data.items():
        f.write(f"{node} {' '.join(map(str, neighbors))}\n")

# %%
link_data_3 = {
    1: [31, 12, 82, 42, 58],
    2: [18, 94, 15, 51, 68],
    3: [41, 17, 82, 87, 52],
    4: [72, 82, 71, 84, 3, 7, 46],
    5: [65, 47, 22, 59, 53, 90],
    6: [61, 24],
    7: [31, 70, 11, 48, 9, 56],
    8: [52, 62, 30, 10],
    9: [74, 59, 72, 35, 91, 71],
    10: [75, 68, 81, 93, 8, 94, 34],
    11: [92, 41, 84, 2, 77, 70, 54],
    12: [14, 31, 8, 85, 54],
    13: [31, 43, 100, 89, 40, 35, 84],
    14: [68],
    15: [1, 38],
    16: [17, 71, 92, 63, 79],
    17: [99],
    18: [21],
    19: [89, 95, 20, 49],
    20: [84, 98, 9, 72, 32],
    21: [29, 7],
    22: [64, 94, 49, 46, 48, 100],
    23: [99, 76, 84, 30],
    24: [10, 8, 73, 49],
    25: [],
    26: [],
    27: [32],
    28: [],
    29: [68, 41, 25, 14, 84, 38],
    30: [83, 65, 8, 72, 73],
    31: [37, 8, 21, 24],
    32: [100, 34],
    33: [97, 2, 75, 99, 78, 96, 67],
    34: [],
    35: [18, 26],
    36: [24],
    37: [39, 22],
    38: [86, 97],
    39: [68, 78, 81, 99, 29, 80],
    40: [21],
    41: [],
    42: [96],
    43: [56, 93, 7, 33, 59],
    44: [66, 47],
    45: [],
    46: [85, 5, 29],
    47: [32, 61, 49, 97],
    48: [84],
    49: [],
    50: [42, 90, 34],
    51: [23, 3, 92],
    52: [11, 9, 85],
    53: [83, 88, 27, 40, 32, 76],
    54: [51, 30, 18, 85, 83, 25, 47],
    55: [40, 82, 63, 5, 58],
    56: [90, 71, 93, 59, 68, 89],
    57: [87, 53, 52, 31, 2, 92],
    58: [56, 35, 81],
    59: [84, 98],
    60: [81, 63, 76, 87, 100],
    61: [35, 82, 5, 41],
    62: [21, 36],
    63: [59, 14],
    64: [55, 66, 73, 10],
    65: [21, 61, 33, 9, 37],
    66: [88, 98, 61, 71, 68, 38],
    67: [93, 29, 97, 60, 44],
    68: [49, 94, 75, 45],
    69: [42],
    70: [48, 26, 25, 3, 53, 81, 65],
    71: [34, 69, 8],
    72: [71, 75, 44, 54],
    73: [86, 23, 70, 83, 84, 2, 53],
    74: [],
    75: [50, 28, 85, 72],
    76: [],
    77: [55, 85, 61, 99, 75, 33, 73],
    78: [28],
    79: [40, 95, 75, 65],
    80: [10],
    81: [15, 92],
    82: [14, 87, 89, 9, 67],
    83: [33, 31, 15, 32, 52],
    84: [67, 94, 91, 78, 73, 45, 89],
    85: [],
    86: [18, 56],
    87: [70, 11, 13, 16, 14, 73],
    88: [68, 24, 67, 17, 91],
    89: [52, 29, 31, 54, 28, 90, 56],
    90: [96, 94],
    91: [21, 54],
    92: [56, 66, 68, 69, 31],
    93: [49, 94, 73, 38, 74, 44, 37],
    94: [75, 76, 83, 85],
    95: [87, 53],
    96: [60, 26, 61, 80, 78],
    97: [86, 81, 98, 91, 56, 18],
    98: [74, 46],
    99: [12, 31, 36, 28, 10, 5, 88],
    100: [56, 62]

}

# %%
link_data_3 = {

1: [38, 95, 36, 67, 94, 65],
2: [32],
3: [97, 49, 34, 20, 83],
4: [78, 65],
5: [97, 56, 32],
6: [35, 33, 39, 8, 82, 94, 17],
7: [75, 11, 28, 78, 17, 14, 37],
8: [92, 83, 84, 77, 94, 24],
9: [60, 81],
10: [37, 40, 18, 11, 100, 44, 89],
11: [39, 57, 22, 26, 63, 30, 8],
12: [47, 95],
13: [42, 73, 97, 50, 3, 92, 4],
14: [42, 79, 87, 63, 36],
15: [2, 95, 94, 83, 42, 67, 60],
16: [96],
17: [78, 16, 73, 8, 18],
18: [94, 28, 29, 64, 69, 37, 36],
19: [40, 84, 25],
20: [79, 15],
21: [61, 67, 37, 24, 23, 96],
22: [23, 13, 99, 69, 89, 52, 88],
23: [62, 53, 77, 31, 63, 80],
24: [38, 35],
25: [19, 72, 47, 99, 44, 39, 94],
26: [40, 98],
27: [15, 28],
28: [94, 45, 73, 71, 7, 100, 25],
29: [38, 36, 79, 39, 2],
30: [15, 5],
31: [88, 97, 45, 22, 65, 79, 29],
32: [81, 96, 52, 70],
33: [39, 73, 70, 99, 47],
34: [5, 71, 7, 67, 95, 16, 62],
35: [4],
36: [95, 81, 42, 53],
37: [18, 75, 98, 29],
38: [35],
39: [29, 21, 17],
40: [52, 73, 30, 90, 10, 33],
41: [86, 92, 84, 63],
42: [16, 14, 8, 36, 5, 54],
43: [94, 11, 77, 5],
44: [97, 17, 66, 54],
45: [70, 46, 98, 7],
46: [47, 64, 62, 77, 90],
47: [68, 7, 1],
48: [63, 13, 6, 79],
49: [54, 19, 2, 63],
50: [36, 99, 83, 58, 89],
51: [35, 82, 36],
52: [20, 22, 4],
53: [30, 97, 94, 70],
54: [20, 93],
55: [100, 5],
56: [10, 99],
57: [23, 4],
58: [82, 37, 85, 96],
59: [25, 39, 28],
60: [96],
61: [79, 98, 2, 18],
62: [9, 95, 6, 51, 60],
63: [27, 70, 13],
64: [57],
65: [43, 46, 99, 41, 53, 32, 33],
66: [80, 27, 40, 11],
67: [84, 85, 13, 12],
68: [90],
69: [43, 65, 64, 18],
70: [82, 11],
71: [90, 19],
72: [94, 96],
73: [53, 95, 91],
74: [19, 92, 75, 69, 54],
75: [27, 23, 3, 92, 78, 74],
76: [58, 100],
77: [71],
78: [11, 43, 95],
79: [14, 97, 94, 9, 100],
80: [27],
81: [7, 87, 96, 17],
82: [1, 47],
83: [29, 35],
84: [8, 65],
85: [52, 7, 57, 22, 73],
86: [68, 94, 96, 12],
87: [47, 70, 92, 19, 79, 99, 25],
88: [15, 55],
89: [2],
90: [73, 11, 68],
91: [52, 6, 63, 35, 17, 54],
92: [53, 2],
93: [68, 42, 98, 55, 100],
94: [45, 98, 61, 33, 77],
95: [56],
96: [8, 31, 80, 75, 72, 85],
97: [80, 64, 3, 58, 53, 17, 15],
98: [13, 30, 2, 66],
99: [83, 35, 66, 48, 67, 34, 16],
100: [29, 84, 56, 27, 64],




}

# %% [markdown]
# # For Spark input data

# %%
file_path = "output.txt"

# Open the file in write mode
with open(file_path, "w") as file:
    # Write the key-value pairs to the file in the desired format
    for key, values in link_data_3.items():
        for value in values:
            file.write(f"{key} {value}\n")

print(f"Data has been saved to {file_path}")
# Out:
# Data has been saved to output.txt

# %%
link_data_3_reduced = {key: [value - 1 for value in values] for key, values in link_data_3.items()}

# %%
link_data = {
    0: [1, 11],
    1: [2, 6],
    2: [1, 0],
    3: [1, 0],
    4: [1],
    5: [0, 1],
    6: [0, 7],
    7: [0, 1, 2, 3, 9],
    8: [0, 5, 9],
    9: [7, 11],
    10: [4, 7],
    11: [0, 10]
}

# %%
print(link_data_3_reduced)
# Out:
# {1: [30, 11, 81, 41, 57], 2: [17, 93, 14, 50, 67], 3: [40, 16, 81, 86, 51], 4: [71, 81, 70, 83, 2, 6, 45], 5: [64, 46, 21, 58, 52, 89], 6: [60, 23], 7: [30, 69, 10, 47, 8, 55], 8: [51, 61, 29, 9], 9: [73, 58, 71, 34, 90, 70], 10: [74, 67, 80, 92, 7, 93, 33], 11: [91, 40, 83, 1, 76, 69, 53], 12: [13, 30, 7, 84, 53], 13: [30, 42, 99, 88, 39, 34, 83], 14: [67], 15: [0, 37], 16: [16, 70, 91, 62, 78], 17: [98], 18: [20], 19: [88, 94, 19, 48], 20: [83, 97, 8, 71, 31], 21: [28, 6], 22: [63, 93, 48, 45, 47, 99], 23: [98, 75, 83, 29], 24: [9, 7, 72, 48], 25: [], 26: [], 27: [31], 28: [], 29: [67, 40, 24, 13, 83, 37], 30: [82, 64, 7, 71, 72], 31: [36, 7, 20, 23], 32: [99, 33], 33: [96, 1, 74, 98, 77, 95, 66], 34: [], 35: [17, 25], 36: [23], 37: [38, 21], 38: [85, 96], 39: [67, 77, 80, 98, 28, 79], 40: [20], 41: [], 42: [95], 43: [55, 92, 6, 32, 58], 44: [65, 46], 45: [], 46: [84, 4, 28], 47: [31, 60, 48, 96], 48: [83], 49: [], 50: [41, 89, 33], 51: [22, 2, 91], 52: [10, 8, 84], 53: [82, 87, 26
# ...

# %%
link_data_3_reduced = {key - 1: [value - 1 for value in values] for key, values in link_data_3.items()}

# Printing the reduced dictionary
print(link_data_3_reduced)
# Out:
# {0: [30, 11, 81, 41, 57], 1: [17, 93, 14, 50, 67], 2: [40, 16, 81, 86, 51], 3: [71, 81, 70, 83, 2, 6, 45], 4: [64, 46, 21, 58, 52, 89], 5: [60, 23], 6: [30, 69, 10, 47, 8, 55], 7: [51, 61, 29, 9], 8: [73, 58, 71, 34, 90, 70], 9: [74, 67, 80, 92, 7, 93, 33], 10: [91, 40, 83, 1, 76, 69, 53], 11: [13, 30, 7, 84, 53], 12: [30, 42, 99, 88, 39, 34, 83], 13: [67], 14: [0, 37], 15: [16, 70, 91, 62, 78], 16: [98], 17: [20], 18: [88, 94, 19, 48], 19: [83, 97, 8, 71, 31], 20: [28, 6], 21: [63, 93, 48, 45, 47, 99], 22: [98, 75, 83, 29], 23: [9, 7, 72, 48], 24: [], 25: [], 26: [31], 27: [], 28: [67, 40, 24, 13, 83, 37], 29: [82, 64, 7, 71, 72], 30: [36, 7, 20, 23], 31: [99, 33], 32: [96, 1, 74, 98, 77, 95, 66], 33: [], 34: [17, 25], 35: [23], 36: [38, 21], 37: [85, 96], 38: [67, 77, 80, 98, 28, 79], 39: [20], 40: [], 41: [95], 42: [55, 92, 6, 32, 58], 43: [65, 46], 44: [], 45: [84, 4, 28], 46: [31, 60, 48, 96], 47: [83], 48: [], 49: [41, 89, 33], 50: [22, 2, 91], 51: [10, 8, 84], 52: [82, 87, 26,
# ...

# %%
input_data = """
1
2 3
3 2
4 1 2
5 4 2 6
6 2 5
7 2 5
8 2 5
9 2 5
10 5
11 5
"""

link_data = {}

for line in input_data.strip().split('\n'):
    values = list(map(int, line.split()))
    link_data[values[0]] = values[1:]

print(link_data)
# Out:
# {1: [], 2: [3], 3: [2], 4: [1, 2], 5: [4, 2, 6], 6: [2, 5], 7: [2, 5], 8: [2, 5], 9: [2, 5], 10: [5], 11: [5]}
